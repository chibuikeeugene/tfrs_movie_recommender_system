# %% [markdown]
# ## Objective - Retrieve relevant candidates of movies

# %%
# load some libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import tensorflow_recommenders as tfrs
import datetime
import faiss
import warnings
import tempfile
import os
warnings.filterwarnings('ignore')

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Clear any logs from previous runs
! rm -rf ./logs/

# %%
from typing import Dict, Text

# %%
# load the data
data = pd.read_csv('sliced_user_id_and_movie_title_data.csv')
data.head()
# Out:
#       userID    movieID                                  originalTitle  \
# 0  ur4592644  tt0120884                           When the Light Comes
# 1  ur3174947  tt0118688                                 Batman & Robin
# 2  ur3780035  tt0387887  Bottom Live 2003: Weapons Grade Y-Fronts Tour
# 3  ur4592628  tt0346491                                      Alexander
# 4  ur3174947  tt0094721                                    Beetlejuice
#
#    rating      review date
# 0      10  16 January 2005
# 1       3  16 January 2005
# 2       8  16 January 2005
# 3       1  16 January 2005
# 4       8  16 January 2005

# %% [markdown]
# ## Step 1: Basic data preprocessing

# %%
# create a new movie title list that enforces type uniformity in its values
# might come in handy when creaying the movie title vocalbulary
updated_movie_titles = []
for i in data['originalTitle']:
    if type(i) != 'str':
        a = str(i)
        updated_movie_titles.append(a)
    else:
        updated_movie_titles.append(i)

# %%
data['originalTitle'] = updated_movie_titles
data['originalTitle']
# Out:
# 0                                 When the Light Comes
# 1                                       Batman & Robin
# 2        Bottom Live 2003: Weapons Grade Y-Fronts Tour
# 3                                            Alexander
# 4                                          Beetlejuice
#                              ...
# 49995               The Five People You Meet in Heaven
# 49996                                         Sin City
# 49997                                         Earthsea
# 49998                                           Léolo
# 49999                                           Sahara
# Name: originalTitle, Length: 50000, dtype: object

# %%
# create a copy of the data
df = data.copy()

# %% [markdown]
# ### Step1.1: convert the string typed review date to datetime format

# %%
# convert the review date to datetime
df['review date'] = pd.to_datetime(df['review date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   userID         50000 non-null  object
#  1   movieID        50000 non-null  object
#  2   originalTitle  50000 non-null  object
#  3   rating         50000 non-null  int64
#  4   review date    50000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.9+ MB

# %%
# sort the data by review date so that we can split the data into training, testing and validation sets
df.sort_values(by='review date', inplace=True)
df.reset_index(drop=True, inplace=True)
df.head(20)
# Out:
#        userID    movieID                  originalTitle  rating review date
# 0   ur4515719  tt0286112                Siu Lam juk kau      10  2005-01-13
# 1   ur1418745  tt0410006                       Gefangen       1  2005-01-13
# 2   ur1495662  tt0036384             Stage Door Canteen       9  2005-01-13
# 3   ur4266247  tt0027661                       Gay Love      10  2005-01-13
# 4   ur3757197  tt0056172             Lawrence of Arabia      10  2005-01-13
# 5   ur2776875  tt0097259                      Easy Kill       1  2005-01-13
# 6   ur0562732  tt0080487                     Caddyshack       5  2005-01-13
# 7   ur4519345  tt0156342                       Barjatri      10  2005-01-13
# 8   ur2766295  tt0438140                     L.A. Dream      10  2005-01-13
# 9   ur4131581  tt0067089                A fekete város      10  2005-01-13
# 10  ur4576555  tt0396041           Gory Gory Hallelujah       9  2005-01-13
# 11  ur0581842  tt0407708              Dai lo oi mei lai       5  2005-01-13
# 12  ur4576512  tt0396041           Gory Gory Hallelujah      10  2005-01-13
# 13  ur3412084  tt0180460  Avanture Borivoja Surdilovica       9  2005-01-13
# 14  ur4312361  tt0425079                 Gönül Yarasi       7  2005-01-13
# 15  ur2950235  tt0077594                  Game of Death       1  2005-01-13
# 16  ur0317399  tt0362269                         Kinsey       8  2005-01-13
# 17  ur2436779  tt0390123    In the Realms of the Unreal       2  2005-01-13
# 18  ur4456861  tt0108399                   True Romance       5  2005-01-13
# 19  ur1307127  tt0340883                     Open House       1  2005-01-13

# %% [markdown]
# ### Step1.2: split the data(into train, test and val) based on date so as you use past records for training

# %%
# split the data into training, testing and validation sets 
train = df[:int(0.7*len(df))]
test = df[int(0.7*len(df)):int(0.85*len(df))]
val = df[int(0.85*len(df)):]
print('train:', train.shape)
print('test:', test.shape)
print('val:', val.shape)
# Out:
# train: (35000, 5)
# test: (7500, 5)
# val: (7500, 5)

# %%
# drop the review date column
train = train.drop('review date', axis=1)
test = test.drop('review date', axis=1)
val = val.drop('review date', axis=1)

# %% [markdown]
# ### Step1.3: Convert the pandas dataset to tensor dataset

# %%
# convert the train, test and val into a tensorflow dataset
train_df = tf.data.Dataset.from_tensor_slices(train.to_dict('list'))
test_df = tf.data.Dataset.from_tensor_slices(test.to_dict('list'))
val_df = tf.data.Dataset.from_tensor_slices(val.to_dict('list'))

# %% [markdown]
# ### Step 1.4: Extract the needed features and create a json object for use in our training

# %%
# selecting just the user id and movie title
train_df = train_df.map(lambda x : {
    'userID': x['userID'],
    'originalTitle': x['originalTitle']
})
test_df = test_df.map(lambda x : {
    'userID': x['userID'],
    'originalTitle': x['originalTitle']
})
val_df = val_df.map(lambda x : {
    'userID': x['userID'],
    'originalTitle': x['originalTitle']
})

# %% [markdown]
# ### Step 1.5: Obtain a movie title and user id tensor items

# %%
# obtaining a movie title list

# first convert df to a tensforflow dataset
df = df.drop('review date', axis= 1)

df_tensor = tf.data.Dataset.from_tensor_slices(df.to_dict('list'))

# select just the movie titles
movie_titles =  df_tensor.map(lambda x: x['originalTitle'])


# selecting just the user id
user_ids = df_tensor.map(lambda x: x['userID'])

# view the movie titles
movie_titles
# Out:
# <_MapDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
for val in movie_titles.take(5).as_numpy_iterator():
    print(val)
# Out:
# b'Siu Lam juk kau'
# b'Gefangen'
# b'Stage Door Canteen'
# b'Gay Love'
# b'Lawrence of Arabia'

# %%
type(user_ids)
# Out:
# tensorflow.python.data.ops.map_op._MapDataset

# %% [markdown]
# ### Step 1.6: Batch and cache the dataset and create a movie and user vocabulary

# %%
# batching the datasets for better performance, speed and memory efficiency
movie_titles_batched = movie_titles.batch(1000)
user_ids_batched = user_ids.batch(1000)


# obtain the unique movie titles and user ids
unique_movie_titles = np.unique(np.concatenate(list(movie_titles_batched)))
unique_user_ids = np.unique(np.concatenate(list(user_ids_batched)))

# %%
unique_movie_titles.shape
# Out:
# (16870,)

# %% [markdown]
# ## Step 2: Model development - 2 tower retrieval model

# %% [markdown]
# ### Query tower

# %%
# define the embedding size or dimension
embedding_dimension = 32

# converting user ids to integers and then to embeddings using keras prprocessing layers
query_model = tf.keras.Sequential([
    tf.keras.layers.StringLookup( # convert the string user ids to integer indices
        vocabulary = unique_user_ids, mask_token=None
    ),
    tf.keras.layers.Embedding( # convert the indices to vector embeddings
        len(unique_user_ids) + 1, embedding_dimension
    )
])

# %% [markdown]
# ## Candidate tower

# %%
movie_model = tf.keras.Sequential([
    tf.keras.layers.StringLookup(
        vocabulary = unique_movie_titles, mask_token =None
    ),
    tf.keras.layers.Embedding(
        len(unique_movie_titles) + 1, embedding_dimension
    )
])

# %% [markdown]
# ## Define Metrics to be observed

# %%
metrics = tfrs.metrics.FactorizedTopK(
    candidates= movie_titles.batch(128).map(movie_model)
)

# %% [markdown]
# ## Define Loss

# %%
tasks  =  tfrs.tasks.Retrieval(
    metrics =  metrics
)

# %% [markdown]
# ## Full Model Architecture

# %%
# using the tfrs.Model class

class Movie_model(tfrs.Model):
    def __init__(self, movie_model, user_model):
        super().__init__()
        self.movie_model: tf.keras.Model = movie_model
        self.user_model: tf.keras.Model = user_model
        self.tasks: tf.keras.layers.Layer =  tasks

    
    def compute_loss(self, features, training = False) -> tf.Tensor:

        # pass the user id feature
        user_embeddings = self.user_model(features['userID'])

        # pass the movie title feature
        positive_movie_embeddings = self.movie_model(features['originalTitle'])

        metrics_and_loss = self.tasks(user_embeddings, positive_movie_embeddings)

        return metrics_and_loss

# %%
tf.random.set_seed(42)
cached_train_df  = train_df.batch(1000).cache()
cached_test_df  = test_df.batch(1000).cache()
cached_val_df  = val_df.batch(1000).cache()

# %% [markdown]
# ## Compiling and Fitting Model

# %%
model = Movie_model(movie_model, query_model)
model.compile(optimizer=tf.keras.optimizers.legacy.Adagrad(learning_rate=0.01))

# using tensorboard for observability
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.fit(cached_train_df, epochs= 10, validation_data=cached_val_df, callbacks=[tensorboard_callback])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adagrad` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adagrad`.
# Epoch 1/10
# 35/35 [==============================] - 36s 1s/step - factorized_top_k/top_1_categorical_accuracy: 8.5714e-05 - factorized_top_k/top_5_categorical_accuracy: 8.5714e-05 - factorized_top_k/top_10_categorical_accuracy: 8.5714e-05 - factorized_top_k/top_50_categorical_accuracy: 2.2857e-04 - factorized_top_k/top_100_categorical_accuracy: 8.0000e-04 - loss: 6902.7845 - regularization_loss: 0.0000e+00 - total_loss: 6902.7845 - val_factorized_top_k/top_1_categorical_accuracy: 0.0011 - val_factorized_top_k/top_5_categorical_accuracy: 0.0011 - val_factorized_top_k/top_10_categorical_accuracy: 0.0011 - val_factorized_top_k/top_50_categorical_accuracy: 0.0013 - val_factorized_top_k/top_100_categorical_accuracy: 0.0020 - val_loss: 3103.4272 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3103.4272
# Epoch 2/10
# 35/35 [==============================] - 34s 981ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0012 - factorized_top_k/top_5_categorical_accuracy: 0.0014 - factorized_top_k/top_10_categorical_accuracy: 0.0021 - factorized_top_k/top_50_categorical_accuracy: 0.0106 - factorized_top_k/top_100_categorical_accuracy: 0.0237 - loss: 6778.6918 - regularization_loss: 0.0000e+00 - total_loss: 6778.6918 - val_factorized_top_k/top_1_categorical_accuracy: 9.3333e-04 - val_factorized_top_k/top_5_categorical_accuracy: 9.3333e-04 - val_factorized_top_k/top_10_categorical_accuracy: 0.0011 - val_factorized_top_k/top_50_categorical_accuracy: 0.0015 - val_factorized_top_k/top_100_categorical_accuracy: 0.0015 - val_loss: 3101.4758 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3101.4758
# Epoch 3/10
# 35/35 [==============================] - 35s 995ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0068 - factorized_top_k/top_5_categorical_accuracy: 0.0076 - factorized_top_k/top_10_categorical_accuracy: 0.0092 - factorized_top_k/top_50_categorical_accuracy: 0.0413 - factorized_top_k/top_100_categorical_accuracy: 0.0745 - loss: 6394.0789 - regularization_loss: 0.0000e+00 - total_loss: 6394.0789 - val_factorized_top_k/top_1_categorical_accuracy: 0.0011 - val_factorized_top_k/top_5_categorical_accuracy: 0.0011 - val_factorized_top_k/top_10_categorical_accuracy: 0.0012 - val_factorized_top_k/top_50_categorical_accuracy: 0.0013 - val_factorized_top_k/top_100_categorical_accuracy: 0.0013 - val_loss: 3118.8979 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3118.8979
# Epoch 4/10
# 35/35 [==============================] - 36s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0242 - factorized_top_k/top_5_categorical_accuracy: 0.0267 - factorized_top_k/top_10_categorical_accuracy: 0.0324 - factorized_top_k/top_50_categorical_accuracy: 0.0992 - factorized_top_k/top_100_categorical_accuracy: 0.1706 - loss: 5794.0119 - regularization_loss: 0.0000e+00 - total_loss: 5794.0119 - val_factorized_top_k/top_1_categorical_accuracy: 9.3333e-04 - val_factorized_top_k/top_5_categorical_accuracy: 9.3333e-04 - val_factorized_top_k/top_10_categorical_accuracy: 9.3333e-04 - val_factorized_top_k/top_50_categorical_accuracy: 0.0012 - val_factorized_top_k/top_100_categorical_accuracy: 0.0020 - val_loss: 3152.9263 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3152.9263
# Epoch 5/10
# 35/35 [==============================] - 35s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0402 - factorized_top_k/top_5_categorical_accuracy: 0.0445 - factorized_top_k/top_10_categorical_accuracy: 0.0617 - factorized_top_k/top_50_categorical_accuracy: 0.1829 - factorized_top_k/top_100_categorical_accuracy: 0.2850 - loss: 5174.9338 - regularization_loss: 0.0000e+00 - total_loss: 5174.9338 - val_factorized_top_k/top_1_categorical_accuracy: 0.0011 - val_factorized_top_k/top_5_categorical_accuracy: 0.0011 - val_factorized_top_k/top_10_categorical_accuracy: 0.0011 - val_factorized_top_k/top_50_categorical_accuracy: 0.0012 - val_factorized_top_k/top_100_categorical_accuracy: 0.0024 - val_loss: 3198.3857 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3198.3857
# Epoch 6/10
# 35/35 [==============================] - 35s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0605 - factorized_top_k/top_5_categorical_accuracy: 0.0707 - factorized_top_k/top_10_categorical_accuracy: 0.1050 - factorized_top_k/top_50_categorical_accuracy: 0.2759 - factorized_top_k/top_100_categorical_accuracy: 0.3831 - loss: 4618.7051 - regularization_loss: 0.0000e+00 - total_loss: 4618.7051 - val_factorized_top_k/top_1_categorical_accuracy: 0.0011 - val_factorized_top_k/top_5_categorical_accuracy: 0.0011 - val_factorized_top_k/top_10_categorical_accuracy: 0.0011 - val_factorized_top_k/top_50_categorical_accuracy: 0.0015 - val_factorized_top_k/top_100_categorical_accuracy: 0.0021 - val_loss: 3250.2427 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3250.2427
# Epoch 7/10
# 35/35 [==============================] - 36s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0745 - factorized_top_k/top_5_categorical_accuracy: 0.0933 - factorized_top_k/top_10_categorical_accuracy: 0.1481 - factorized_top_k/top_50_categorical_accuracy: 0.3512 - factorized_top_k/top_100_categorical_accuracy: 0.4615 - loss: 4117.7153 - regularization_loss: 0.0000e+00 - total_loss: 4117.7153 - val_factorized_top_k/top_1_categorical_accuracy: 6.6667e-04 - val_factorized_top_k/top_5_categorical_accuracy: 6.6667e-04 - val_factorized_top_k/top_10_categorical_accuracy: 6.6667e-04 - val_factorized_top_k/top_50_categorical_accuracy: 0.0017 - val_factorized_top_k/top_100_categorical_accuracy: 0.0027 - val_loss: 3303.3115 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3303.3115
# Epoch 8/10
# 35/35 [==============================] - 36s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0912 - factorized_top_k/top_5_categorical_accuracy: 0.1227 - factorized_top_k/top_10_categorical_accuracy: 0.1949 - factorized_top_k/top_50_categorical_accuracy: 0.4194 - factorized_top_k/top_100_categorical_accuracy: 0.5284 - loss: 3670.0329 - regularization_loss: 0.0000e+00 - total_loss: 3670.0329 - val_factorized_top_k/top_1_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_10_categorical_accuracy: 5.3333e-04 - val_factorized_top_k/top_50_categorical_accuracy: 0.0015 - val_factorized_top_k/top_100_categorical_accuracy: 0.0029 - val_loss: 3360.9133 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3360.9133
# Epoch 9/10
# 35/35 [==============================] - 36s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.1037 - factorized_top_k/top_5_categorical_accuracy: 0.1531 - factorized_top_k/top_10_categorical_accuracy: 0.2414 - factorized_top_k/top_50_categorical_accuracy: 0.4745 - factorized_top_k/top_100_categorical_accuracy: 0.5850 - loss: 3275.0549 - regularization_loss: 0.0000e+00 - total_loss: 3275.0549 - val_factorized_top_k/top_1_categorical_accuracy: 6.6667e-04 - val_factorized_top_k/top_5_categorical_accuracy: 8.0000e-04 - val_factorized_top_k/top_10_categorical_accuracy: 9.3333e-04 - val_factorized_top_k/top_50_categorical_accuracy: 0.0017 - val_factorized_top_k/top_100_categorical_accuracy: 0.0028 - val_loss: 3411.9780 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3411.9780
# Epoch 10/10
# 35/35 [==============================] - 36s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.1150 - factorized_top_k/top_5_categorical_accuracy: 0.1862 - factorized_top_k/top_10_categorical_accuracy: 0.2836 - factorized_top_k/top_50_categorical_accuracy: 0.5211 - factorized_top_k/top_100_categorical_accuracy: 0.6241 - loss: 2929.7632 - regularization_loss: 0.0000e+00 - total_loss: 2929.7632 - val_factorized_top_k/top_1_categorical_accuracy: 5.3333e-04 - val_factorized_top_k/top_5_categorical_accuracy: 6.6667e-04 - val_factorized_top_k/top_10_categorical_accuracy: 8.0000e-04 - val_factorized_top_k/top_50_categorical_accuracy: 0.0013 - val_factorized_top_k/top_100_categorical_accuracy: 0.0024 - val_loss: 3464.8481 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3464.8481

# %% [markdown]
# ## Predicting or recommending for new user

# %%
# user BruteForce from factorized top-k

# creating the model that takes in raw query features
index = tfrs.layers.factorized_top_k.BruteForce(model.user_model)

# recommends movie out of the entire dataset
index.index_from_dataset(
    tf.data.Dataset.zip(
        (movie_titles.batch(100), movie_titles.batch(100).map(model.movie_model))
)
)

# getting recommendations
# Get recommendations.
_, titles = index(tf.constant(['ur3174947']))
print(f"Recommendations for user ur3174947: {titles[0, :10]}")
# Out:
# Recommendations for user ur3174947: [b'Old School' b'Old School' b'Old School' b'Old School' b'Old School'
#  b'Old School' b'Old School' b'Old School' b'Old School' b'Mrs. Doubtfire']

# %% [markdown]
# # Since BruteForce is slow for serving a model with many possible candidates we explore approximate retrieval index

# %%
# Using FAISS for approximate retrieval operation

# creating a distance based indices
faiss_index = faiss.IndexFlatL2(embedding_dimension)


# list to store movied ids. This will be used to retrieve the movie names later
movie_ids_list = []

# a function to index movie embeddings in FAISS
def index_movie_in_faiss(movies, movie_ids):
    # retrieve movie embeddings
    movie_embeddings = model.movie_model(movies)

    # Check the shape of the embeddings
    print(f'shape of the movie_embeddings: {movie_embeddings.shape}')

    # convert to a numpy array
    movie_embeddings_np = movie_embeddings.numpy()

    # add the movie embeddings to the faiss index
    faiss_index.add(movie_embeddings_np)

    # Update the movie ID list (ensure the order is consistent)
    movie_ids_list.extend(movie_ids)  # Add the movie IDs of the current batch

    print(f'length of the variable - movie_ids_list: {len(movie_ids_list)}') # for observability

# %%
# function to perform similarity search
def search_top_k(user_id, k):
    # get the user embeddings and convert it to numpy array
    user_embeddings = model.user_model(user_id)
    user_embeddings_np = user_embeddings.numpy()

    # performing search in faiss index
    distances, indices = faiss_index.search(user_embeddings_np, k)

    # Print indices for debugging
    print(f"indices: {indices}")

    # Convert indices to movie IDs using the mapping
    recommended_movie_ids = []
    for index in indices:
        # print(index)
        movie_id_for_each_index = [movie_ids_list[i] for i in index] # Retrieve movie IDs for each index
        recommended_movie_ids.append(movie_id_for_each_index)

    return distances, recommended_movie_ids

# %%
movie_titles_with_ids =  df_tensor.map(lambda x: 
    {
    'movieID': x['movieID'],
    'originalTitle': x['originalTitle']
    }
)


for movie in movie_titles_with_ids.batch(100).as_numpy_iterator():
    # Assume movie_batch contains a list of movie features and movie_ids_batch is a list of IDs
    movie_ids_batch = [mov for mov in movie['movieID']]  # return the movie ids for the batch
    # print(f'length of the movie_ids for a 100 batch: {len(movie_ids_batch)}')
    index_movie_in_faiss(movie['originalTitle'], movie_ids_batch)

# searching for the top k most similar movies for a user
user = tf.constant(['ur3174947'])
distances, recommended_movie_ids = search_top_k(user, k=10)

# Print the recommended movie IDs for the user
print(f"Recommended Movie IDs: {recommended_movie_ids}")
# Out:
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 1900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 2900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 3900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 4900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 5900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 6900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 7900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 8900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 9900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 10900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 11900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 12900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 13900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 14900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 15900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 16900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 17900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 18900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 19900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 20900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 21900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 22900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 23900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 24900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 25900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 26900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 27900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 28900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 29900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 30900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 31900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 32900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 33900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 34900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 35900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 36900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 37900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 38900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 39900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 40900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 41900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 42900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 43900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 44900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 45900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 46900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 47900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 48900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 49900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50000
# indices: [[ 5696 39693 40073 49858  5661  5214  1133 26344  1293 19072]]
# Recommended Movie IDs: [[b'tt0151738', b'tt0151738', b'tt0151738', b'tt0151738', b'tt0067528', b'tt0071613', b'tt0101605', b'tt0101605', b'tt0115956', b'tt0115956']]

# %%
for movie in movie_titles_with_ids.take(20).batch(10).as_numpy_iterator():
    print(movie['movieID'])
# Out:
# [b'tt0286112' b'tt0410006' b'tt0036384' b'tt0027661' b'tt0056172'
#  b'tt0097259' b'tt0080487' b'tt0156342' b'tt0438140' b'tt0067089']
# [b'tt0396041' b'tt0407708' b'tt0396041' b'tt0180460' b'tt0425079'
#  b'tt0077594' b'tt0362269' b'tt0390123' b'tt0108399' b'tt0340883']

# %%
# removing duplicates from result
final_movie_recommended_ids = list(dict.fromkeys(recommended_movie_ids[0]))
final_movie_recommended_ids
# Out:
# [b'tt0151738', b'tt0067528', b'tt0071613', b'tt0101605', b'tt0115956']

# %%
# converting byte strings to string
recommended_movie_str =[val.decode(encoding='utf-8') for val in final_movie_recommended_ids]
recommended_movie_str
# Out:
# ['tt0151738', 'tt0067528', 'tt0071613', 'tt0101605', 'tt0115956']

# %%
# FAISS Retrival claas
class Faiss_retrieval_index():
    """ Using FAISS for approximate retrieval operation 
    
    * args:
    embedding_dimension: The dimension size of the vectors

    * model: This is the already compiled and trained_model
    """

    # list to store movie ids. This will be used to retrieve the movie names later
    movie_ids_list = []

    def __init__(self, embedding_dimension, model):
        self.embedding_dimension = embedding_dimension
        self.movie_model = model.movie_model
        self.query_model = model.user_model
        # creating a distance based indices
        self.faiss_index = faiss.IndexFlatL2(self.embedding_dimension)


    # a function to index movie embeddings in FAISS
    def index_movie_in_faiss(self, movies, movie_ids):
        """ function that index movie embeddings

        args:
        * movies -  a batch of movie title list derived from a tensor dataset

        * movie_ids - the ids of the batch of movie title list
        
        """
        # retrieve movie embeddings
        movie_embeddings = self.movie_model(movies)

        # Check the shape of the embeddings
        print(f'shape of the movie_embeddings: {movie_embeddings.shape}')

        # convert to a numpy array
        movie_embeddings_np = movie_embeddings.numpy()

        # add the movie embeddings to the faiss index
        self.faiss_index.add(movie_embeddings_np)

        # Update the movie ID list (ensure the order is consistent)
        movie_ids_list.extend(movie_ids)  # Add the movie IDs of the current batch

        print(f'length of the variable - movie_ids_list: {len(movie_ids_list)}') # for observability
    
    # function to perform similarity search
    def search_top_k(self, user_id, k):
        """ perform similarity search of the query with the existing embeddings
        
        args:
        * user_id: the id which represents the query we hope to find a result for

        * k: the number of possible result to be returned
        """

        # get the user embeddings and convert it to numpy array
        user_embeddings = self.query_model(user_id)
        user_embeddings_np = user_embeddings.numpy()

        # performing search in faiss index
        distances, indices = self.faiss_index.search(user_embeddings_np, k)

        # Print indices for debugging
        print(f"indices: {indices}")

        # Convert indices to movie IDs using the mapping
        recommended_movie_ids = []
        for index in indices:
            # print(index)
            movie_id_for_each_index = [movie_ids_list[i] for i in index] # Retrieve movie IDs for each index
            recommended_movie_ids.append(movie_id_for_each_index)

        return distances, recommended_movie_ids

# %%
faiss_retrieval =  Faiss_retrieval_index(embedding_dimension=32, model=model)
movie_titles_with_ids =  df_tensor.map(lambda x: 
    {
    'movieID': x['movieID'],
    'originalTitle': x['originalTitle']
    }
)


for movie in movie_titles_with_ids.batch(100).as_numpy_iterator():
    movie_ids_batch = [mov for mov in movie['movieID']]  # return the movie ids for the batch
    faiss_retrieval.index_movie_in_faiss(movie['originalTitle'], movie_ids_batch)

# searching for the top k most similar movies for a user
user = tf.constant(['ur3174947'])
distances, recommended_movie_ids = faiss_retrieval.search_top_k(user, k=10)

# Print the recommended movie IDs for the user
print(f"Recommended Movie IDs: {recommended_movie_ids}")
# Out:
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 50900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 51900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 52900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 53900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 54900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 55900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 56900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 57900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 58900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 59900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 60900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 61900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 62900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 63900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 64900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 65900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 66900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 67900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 68900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 69900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 70900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 71900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 72900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 73900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 74900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 75900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 76900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 77900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 78900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 79900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 80900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 81900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 82900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 83900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 84900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 85900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 86900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 87900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 88900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 89900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 90900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 91900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 92900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 93900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 94900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 95900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 96900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 97900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 98900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 99900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100000
# indices: [[ 5696 39693 40073 49858  5661  5214  1133 26344  1293 19072]]
# Recommended Movie IDs: [[b'tt0151738', b'tt0151738', b'tt0151738', b'tt0151738', b'tt0067528', b'tt0071613', b'tt0101605', b'tt0101605', b'tt0115956', b'tt0115956']]
