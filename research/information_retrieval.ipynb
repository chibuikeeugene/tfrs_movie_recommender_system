# %% [markdown]
# ## Objective - Information Retrieval:: Retrieve relevant movie candidates

# %%
# load some libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import tensorflow_recommenders as tfrs
import datetime
import faiss
import warnings
import tempfile
from typing import Dict, Text
import os
warnings.filterwarnings('ignore')

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Clear any logs from previous runs
! rm -rf ./logs/

# %%
# load the data
ratings_data = pd.read_csv('../data_files/title.basics.csv')
users_data = pd.read_csv('../data_files/title.user-rating.csv')

#select needed features from ratings
ratings_data = ratings_data[['tconst', 'originalTitle', 'genres', 'runtimeMinutes']]

# rename column
ratings_data.rename(columns={'tconst': 'movieID'}, inplace=True)

data = users_data.merge(ratings_data, on='movieID')
data.head()
# Out:
#       userID    movieID  rating      review date  \
# 0  ur4592644  tt0120884      10  16 January 2005
# 1  ur3174947  tt0118688       3  16 January 2005
# 2  ur3780035  tt0387887       8  16 January 2005
# 3  ur4592628  tt0346491       1  16 January 2005
# 4  ur3174947  tt0094721       8  16 January 2005
#
#                                    originalTitle                   genres  \
# 0                           When the Light Comes  Adventure,Drama,Romance
# 1                                 Batman & Robin            Action,Sci-Fi
# 2  Bottom Live 2003: Weapons Grade Y-Fronts Tour                   Comedy
# 3                                      Alexander   Action,Biography,Drama
# 4                                    Beetlejuice           Comedy,Fantasy
#
#   runtimeMinutes
# 0            115
# 1            125
# 2             93
# 3            175
# 4             92

# %%
data.shape
# Out:
# (2400016, 7)

# %% [markdown]
# ## Step 1: Basic data preprocessing

# %%
# create a new movie title list that enforces type uniformity in its values
# might come in handy when creaying the movie title vocalbulary
updated_movie_titles = []
for i in data['originalTitle']:
    if type(i) != 'str':
        a = str(i)
        updated_movie_titles.append(a)
    else:
        updated_movie_titles.append(i)

# %%
data['originalTitle'] = updated_movie_titles
data['originalTitle']
# Out:
# 0                                   When the Light Comes
# 1                                         Batman & Robin
# 2          Bottom Live 2003: Weapons Grade Y-Fronts Tour
# 3                                              Alexander
# 4                                            Beetlejuice
#                                ...
# 2400011                        Robin Hood: Men in Tights
# 2400012                                   Batman Returns
# 2400013                          Lipstick on Your Collar
# 2400014                                  Out for Justice
# 2400015                                     The I Inside
# Name: originalTitle, Length: 2400016, dtype: object

# %%
# Due to data size and training time, we will use some records
df = data.sample(n = 100000, random_state = 50, axis = 0)

# %%
df.shape
# Out:
# (100000, 7)

# %% [markdown]
# ### Step1.1: convert the string typed review date to datetime format

# %%
# convert the review date to datetime
df['review date'] = pd.to_datetime(df['review date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 235927 to 575509
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   userID          100000 non-null  object
#  1   movieID         100000 non-null  object
#  2   rating          100000 non-null  int64
#  3   review date     100000 non-null  datetime64[ns]
#  4   originalTitle   100000 non-null  object
#  5   genres          100000 non-null  object
#  6   runtimeMinutes  100000 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 6.1+ MB

# %%
# convert the datetime to just unix timestamp
df['review date in unix'] = [datetime.datetime.timestamp(time) for time in df['review date']]
df.head()
# Out:
#             userID    movieID  rating review date  \
# 235927   ur9821471  tt0434409      10  2006-03-18
# 553747  ur15651776  tt0076070       6  2007-08-23
# 448345  ur13504572  tt0300015       8  2007-01-28
# 612775   ur4481891  tt0401383       9  2008-01-06
# 989315   ur0565973  tt0110413      10  2002-11-03
#
#                        originalTitle                 genres runtimeMinutes  \
# 235927                V for Vendetta    Action,Drama,Sci-Fi            132
# 553747                  The Gauntlet  Action,Crime,Thriller            109
# 448345          I Capture the Castle          Drama,Romance            113
# 612775  Le scaphandre et le papillon        Biography,Drama            112
# 989315                         L√©on     Action,Crime,Drama            110
#
#         review date in unix
# 235927         1.142640e+09
# 553747         1.187824e+09
# 448345         1.169942e+09
# 612775         1.199578e+09
# 989315         1.036282e+09

# %%
# sort the data by review date so that we can split the data into training, testing and validation sets
df.sort_values(by='review date', inplace=True)
df.reset_index(drop=True, inplace=True)
df.head(20)
# Out:
#        userID    movieID  rating review date  \
# 0   ur0000002  tt0134619       4  1998-07-27
# 1   ur0000059  tt0119822       8  1998-07-29
# 2   ur0053637  tt0120746      10  1998-07-29
# 3   ur0086088  tt0119668       1  1998-07-31
# 4   ur0087139  tt0134619       7  1998-07-31
# 5   ur0089183  tt0120591      10  1998-08-01
# 6   ur0087349  tt0120685       3  1998-08-02
# 7   ur0086207  tt0120591      10  1998-08-02
# 8   ur0068895  tt0120609       9  1998-08-02
# 9   ur0085471  tt0114369       9  1998-08-02
# 10  ur0011321  tt0117887       8  1998-08-03
# 11  ur0070226  tt0111309       8  1998-08-04
# 12  ur0090329  tt0118789      10  1998-08-04
# 13  ur0064529  tt0088040       8  1998-08-04
# 14  ur0087437  tt0114694      10  1998-08-05
# 15  ur0068788  tt0119314       1  1998-08-05
# 16  ur0072439  tt0107843       3  1998-08-05
# 17  ur0019738  tt0116209      10  1998-08-06
# 18  ur0008357  tt0017739       9  1998-08-06
# 19  ur0084211  tt0120184       1  1998-08-06
#
#                               originalTitle                   genres  \
# 0                       Disturbing Behavior    Horror,Mystery,Sci-Fi
# 1                        As Good as It Gets     Comedy,Drama,Romance
# 2                         The Mask of Zorro  Action,Adventure,Comedy
# 3   Midnight in the Garden of Good and Evil      Crime,Drama,Mystery
# 4                       Disturbing Behavior    Horror,Mystery,Sci-Fi
# 5                                Armageddon  Action,Adventure,Sci-Fi
# 6                                  Godzilla   Action,Sci-Fi,Thriller
# 7                                Armageddon  Action,Adventure,Sci-Fi
# 8                               The Big Hit      Action,Comedy,Crime
# 9                                     Se7en      Crime,Drama,Mystery
# 10                       That Thing You Do!       Comedy,Drama,Music
# 11                            The Sum of Us             Comedy,Drama
# 12                              Buffalo '66     Comedy,Drama,Romance
# 13                     Los santos inocentes                    Drama
# 14                                Tommy Boy         Adventure,Comedy
# 15                      The Horse Whisperer    Drama,Romance,Western
# 16                       Point of No Return       Action,Crime,Drama
# 17                      The English Patient        Drama,Romance,War
# 18                   The Cat and the Canary    Comedy,Horror,Mystery
# 19                                   Sphere    Action,Mystery,Sci-Fi
#
#    runtimeMinutes  review date in unix
# 0              84          901494000.0
# 1             139          901666800.0
# 2             136          901666800.0
# 3             155          901839600.0
# 4              84          901839600.0
# 5             151          901926000.0
# 6             139          902012400.0
# 7             151          902012400.0
# 8              91          902012400.0
# 9             127          902012400.0
# 10            108          902098800.0
# 11            100          902185200.0
# 12            110          902185200.0
# 13            107          902185200.0
# 14             97          902271600.0
# 15            169          902271600.0
# 16            109          902271600.0
# 17            162          902358000.0
# 18            108          902358000.0
# 19            134          902358000.0

# %% [markdown]
# ### Step1.2: split the data(into train, test and val) based on date so as you use past records for training

# %%
# split the data into training, testing and validation sets 
train = df[:int(0.7*len(df))]
test = df[int(0.7*len(df)):int(0.85*len(df))]
val = df[int(0.85*len(df)):]
print('train:', train.shape)
print('test:', test.shape)
print('val:', val.shape)
# Out:
# train: (70000, 8)
# test: (15000, 8)
# val: (15000, 8)

# %%
# drop the review date column
train = train.drop('review date', axis=1)
test = test.drop('review date', axis=1)
val = val.drop('review date', axis=1)

# %% [markdown]
# ### Step1.3: Convert the pandas dataset to tensor dataset

# %%
# convert the train, test and val into a tensorflow dataset
train_df = tf.data.Dataset.from_tensor_slices(train.to_dict('list'))
test_df = tf.data.Dataset.from_tensor_slices(test.to_dict('list'))
val_df = tf.data.Dataset.from_tensor_slices(val.to_dict('list'))
# Out:
# 2025-04-08 16:30:53.804933: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-04-08 16:30:53.804968: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-04-08 16:30:53.804979: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-04-08 16:30:53.805011: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-08 16:30:53.805028: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Step 1.4: Extract the needed features and create a json object for use in our training

# %%
# selecting just the user id, movie title, ratings, genres, runtimemins and reviewdate
train_df = train_df.map(lambda x : {
    'userID': x['userID'],
    'originalTitle': x['originalTitle'],
    'rating':x['rating'],
    'genres': x['genres'],
    'runtimeMinutes': x['runtimeMinutes'],
    'review date in unix': x['review date in unix']
    
})
test_df = test_df.map(lambda x : {
    'userID': x['userID'],
    'originalTitle': x['originalTitle'],
    'rating':x['rating'],
    'genres': x['genres'],
    'runtimeMinutes': x['runtimeMinutes'],
    'review date in unix': x['review date in unix']
})
val_df = val_df.map(lambda x : {
    'userID': x['userID'],
    'originalTitle': x['originalTitle'],
    'rating':x['rating'],
    'genres': x['genres'],
    'runtimeMinutes': x['runtimeMinutes'],
    'review date in unix': x['review date in unix']
})

# %%
for data in val_df.take(1).as_numpy_iterator(): # to check if our selection worked
    print(data)
# Out:
# {'userID': b'ur0482513', 'originalTitle': b'Psyche 59', 'rating': 3, 'genres': b'Drama,Mystery,Romance', 'runtimeMinutes': b'94', 'review date in unix': 1533769200.0}

# %% [markdown]
# ### Step 1.5: Obtain a movie title and user id tensor items

# %%
# obtaining a movie title list

# first convert df to a tensorflow dataset
df = df.drop('review date', axis= 1)

df_tensor = tf.data.Dataset.from_tensor_slices(df.to_dict('list'))


## ===== these will come in handy when creating our vocabularies
# select just the movie titles
movie_titles =  df_tensor.map(lambda x: x['originalTitle'])

# select just the genre
genres =  df_tensor.map(lambda x: x['genres'])

movietitle_genres = df_tensor.map( lambda x: {
        'originalTitle' : x['originalTitle'],
        'genres': x['genres']
    }
)

# select just the review date unix timestamp
timestamp =  df_tensor.map(lambda x: x['review date in unix'])

# selecting just the user id
user_ids = df_tensor.map(lambda x: x['userID'])

# view the movie titles
movie_titles
# Out:
# <_MapDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
for val in movie_titles.take(5).as_numpy_iterator():
    print(val)
# Out:
# b'Disturbing Behavior'
# b'As Good as It Gets'
# b'The Mask of Zorro'
# b'Midnight in the Garden of Good and Evil'
# b'Disturbing Behavior'

# %%
for val in movietitle_genres.take(5).as_numpy_iterator():
    print(val)
# Out:
# {'originalTitle': b'Disturbing Behavior', 'genres': b'Horror,Mystery,Sci-Fi'}
# {'originalTitle': b'As Good as It Gets', 'genres': b'Comedy,Drama,Romance'}
# {'originalTitle': b'The Mask of Zorro', 'genres': b'Action,Adventure,Comedy'}
# {'originalTitle': b'Midnight in the Garden of Good and Evil', 'genres': b'Crime,Drama,Mystery'}
# {'originalTitle': b'Disturbing Behavior', 'genres': b'Horror,Mystery,Sci-Fi'}

# %% [markdown]
# ### Step 1.6: Create a movie, timestamp and user vocabulary. While for the genres, we will apply text vectorization technique later

# %%
# NB: batching the mapdataset introduces dimension.
movie_titles_batched = movie_titles.batch(1000)
user_ids_batched = user_ids.batch(1000)
timestamp_batched=timestamp.batch(1000)
genres_batched = genres.batch(1000)


# obtain the unique movie titles and user ids
unique_movie_titles = np.unique(np.concatenate(list(movie_titles_batched)))
unique_user_ids = np.unique(np.concatenate(list(user_ids_batched)))
timestamp =  np.concatenate(list(timestamp_batched)) # no need to obtain unique timestamp. it most likely wiil be different
unique_genres = np.unique(np.concatenate(list(genres_batched)))

# for our timestamp we will apply standardization or normalization technique,
# We will also create its embeddings. Its embeddings can be gotten by first creating a bucketed timestamp which then acts more categorical 
#Hence, we obtain the bucketed timestamp to be used later

max_timestamp = timestamp.max()
min_timestamp = timestamp.min()

timestamp_bucket = np.linspace(
    min_timestamp, max_timestamp, num=1000)

# %%
unique_movie_titles.shape
# Out:
# (34132,)

# %%
timestamp_bucket[:50]
# Out:
# array([9.01494016e+08, 9.02200182e+08, 9.02906347e+08, 9.03612513e+08,
#        9.04318679e+08, 9.05024845e+08, 9.05731010e+08, 9.06437176e+08,
#        9.07143342e+08, 9.07849508e+08, 9.08555673e+08, 9.09261839e+08,
#        9.09968005e+08, 9.10674171e+08, 9.11380336e+08, 9.12086502e+08,
#        9.12792668e+08, 9.13498834e+08, 9.14204999e+08, 9.14911165e+08,
#        9.15617331e+08, 9.16323497e+08, 9.17029662e+08, 9.17735828e+08,
#        9.18441994e+08, 9.19148160e+08, 9.19854325e+08, 9.20560491e+08,
#        9.21266657e+08, 9.21972823e+08, 9.22678988e+08, 9.23385154e+08,
#        9.24091320e+08, 9.24797486e+08, 9.25503651e+08, 9.26209817e+08,
#        9.26915983e+08, 9.27622149e+08, 9.28328314e+08, 9.29034480e+08,
#        9.29740646e+08, 9.30446812e+08, 9.31152977e+08, 9.31859143e+08,
#        9.32565309e+08, 9.33271475e+08, 9.33977640e+08, 9.34683806e+08,
#        9.35389972e+08, 9.36096138e+08])

# %% [markdown]
# ## Step 2: Model development - 2 tower retrieval model

# %% [markdown]
# ### Query tower

# %%
class UserModel(tf.keras.Model):

    def __init__(self, use_timestamp):
        super().__init__()
        
        self.use_timestamp =  use_timestamp
        
        # converting user ids to integers and then to embeddings using keras preprocessing layers
        self.user_embedding = tf.keras.Sequential(
            [
            tf.keras.layers.StringLookup( # convert the string user ids to integer indices
                vocabulary = unique_user_ids, mask_token=None
            ),
            tf.keras.layers.Embedding( # convert the indices to vector embeddings
                len(unique_user_ids) + 1, 32
            )
            ]
        )

        #  incorporating timestamps to model user preferences at a point in time.
        
        # depending on the timestamp value it switches on and off this feature influence in our matrix computation 
        # dual operations: Firstly: obtain timestamp embeddings
        if self.use_timestamp:
            self.timestamp_embeddings = tf.keras.Sequential([
                tf.keras.layers.Discretization(
                    timestamp_bucket.tolist()
                ),
                tf.keras.layers.Embedding(
                    len(timestamp_bucket) + 1, 32
                )
            ])
            # Secondly normalize timestamp
            self.normalized_timestamp =  tf.keras.layers.Normalization(
                axis=None
            )
            self.normalized_timestamp.adapt(timestamp)

    def call(self, inputs):
        if not self.use_timestamp:
            return self.user_embedding(inputs['userID'])

        return tf.concat(
            [
            self.user_embedding(inputs['userID']),
            self.timestamp_embeddings(inputs['review date in unix']),
            tf.reshape(self.normalized_timestamp(inputs['review date in unix']), (-1, 1))
        ], axis=1)

# %%
# To capture more complex relationships, such as user preferences evolving over time, 
# we may need a deeper model with multiple stacked dense layers - Deep query retrieval model

# Full Query model
class QueryModel(tf.keras.Model):
    """ model for encoding user features """
    
    def __init__(self, layer_sizes, use_timestamp):

        """ initialize the user model embedding layer and the dense layer
        Args:
        * layer_sizes: a list of inttegers to create the dense layer depth

        * use_timestamp -  a boolean variable - that helps introduce some additional impact on the relationship between timing and user's preference
        
        """
        super().__init__()

        # pass the user model
        self.query_embedding_model = UserModel(use_timestamp)

        # add the dense layer
        self.dense_layers = tf.keras.Sequential()

        # using the relu activation for all the layers except the last. This helps introduce non-linearity for
        # studying complex relationships
        for layer in layer_sizes[:-1]:
            self.dense_layers.add(tf.keras.layers.Dense(layer, activation='relu'))

        # for the last layer
        for layer in layer_sizes[-1:]:
            self.dense_layers.add(tf.keras.layers.Dense(layer))

    def call(self, inputs):
        feature_embeddings = self.query_embedding_model(inputs)
        return self.dense_layers(feature_embeddings)

# %% [markdown]
# ## Candidate tower

# %%
class MovieModel(tf.keras.Model):
    def __init__(self):
        super().__init__()
        max_token = 10000 # maximum number of tokens to be generated in the vocabulary

        self.movie_embeddings = tf.keras.Sequential(
            [
            tf.keras.layers.StringLookup(
                vocabulary = unique_movie_titles, mask_token =None
            ),
            tf.keras.layers.Embedding(
                len(unique_movie_titles) + 1, 32
            )
            ]
        )

        self.genre_embeddings = tf.keras.Sequential([
            tf.keras.layers.TextVectorization(
                max_tokens=max_token,
                vocabulary= unique_genres
            ),
            tf.keras.layers.Embedding(
                max_token, 32, mask_zero=True
            ),
            tf.keras.layers.GlobalAveragePooling1D(),
        ])

    def call(self, inputs):
        
        return tf.concat([
            self.movie_embeddings(inputs['originalTitle']),
            self.genre_embeddings(inputs['genres'])
        ], axis=1)

# %%
# Full candidate deep model

class CandidateModel(tf.keras.Model):

    """ model for encoding candidate features """

    def __init__(self, layer_sizes):

        """ initialize the movie model embedding layer and the dense layer"""

        super().__init__()

        # pass the movie model
        self.candidate_embedding_model = MovieModel()

        # add the dense layers
        self.dense_layers =  tf.keras.Sequential()

        for layer in layer_sizes[:-1]:
            self.dense_layers.add(tf.keras.layers.Dense(layer, activation='relu'))

        # capturing the last dense layer
        for layer in layer_sizes[-1:]:
            self.dense_layers.add(tf.keras.layers.Dense(layer))
                                  
    def call(self, inputs):

        feature_embeddings = self.candidate_embedding_model(inputs)
        return self.dense_layers(feature_embeddings)

# %%
list(genres)[:10] # just inspecting the genres tensor dataset
# Out:
# [<tf.Tensor: shape=(), dtype=string, numpy=b'Horror,Mystery,Sci-Fi'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Comedy,Drama,Romance'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Action,Adventure,Comedy'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Crime,Drama,Mystery'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Horror,Mystery,Sci-Fi'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Action,Adventure,Sci-Fi'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Action,Sci-Fi,Thriller'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Action,Adventure,Sci-Fi'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Action,Comedy,Crime'>,
#  <tf.Tensor: shape=(), dtype=string, numpy=b'Crime,Drama,Mystery'>]

# %% [markdown]
# ## Full Model Architecture

# %%
# using the tfrs.Model class to wrap our two-tower model architecture and define metrics and loss functions

class FinalModel(tfrs.models.Model):
    def __init__(self, layer_sizes, use_timestamp):
        super().__init__()
    
        self.query_model: tf.keras.Model = QueryModel(layer_sizes, use_timestamp)
        self.candidate_model: tf.keras.Model = CandidateModel(layer_sizes)
        self.tasks =  tfrs.tasks.Retrieval(
            metrics=tfrs.metrics.FactorizedTopK(
                candidates= movietitle_genres.batch(128).map(self.candidate_model)
            )
        )

    
    def compute_loss(self, features, training = False) -> tf.Tensor:

        # pass the user id feature
        user_embeddings = self.query_model(features)

        # pass the movie title feature
        positive_movie_embeddings = self.candidate_model(features)

        metrics_and_loss = self.tasks(user_embeddings, positive_movie_embeddings)

        return metrics_and_loss

# %%
# batching the datasets for better performance, speed and memory efficiency
tf.random.set_seed(42)
cached_train_df  = train_df.batch(1000).cache()
cached_test_df  = test_df.batch(1000).cache()
cached_val_df  = val_df.batch(1000).cache()

# %% [markdown]
# ## Compiling and Fitting Model

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# using tensorboard for observability
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# Defining callback objects
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='loss', patience=7),
    tf.keras.callbacks.ModelCheckpoint(filepath='logs/models', save_weights_only=True, save_best_only=True, save_freq="epoch",),
    tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
]

model = FinalModel([32],use_timestamp=True)
optimize = tf.keras.optimizers.legacy.Adam(learning_rate=0.01)
model.compile(optimizer=optimize)

with tf.device('/GPU:0'): # setting tensorflow to run the fit operation on GPU
    model.fit(cached_train_df, epochs= 10, validation_data=cached_val_df, callbacks= callbacks)
# Out:
# Epoch 1/10
# 70/70 [==============================] - 281s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.3989 - factorized_top_k/top_5_categorical_accuracy: 0.4128 - factorized_top_k/top_10_categorical_accuracy: 0.4184 - factorized_top_k/top_50_categorical_accuracy: 0.4607 - factorized_top_k/top_100_categorical_accuracy: 0.4812 - loss: 6907.2798 - regularization_loss: 0.0000e+00 - total_loss: 6907.2798 - val_factorized_top_k/top_1_categorical_accuracy: 2.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 2.0000e-04 - val_factorized_top_k/top_10_categorical_accuracy: 2.0000e-04 - val_factorized_top_k/top_50_categorical_accuracy: 4.6667e-04 - val_factorized_top_k/top_100_categorical_accuracy: 0.0013 - val_loss: 6908.4414 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6908.4414
# Epoch 2/10
# 70/70 [==============================] - 278s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.0018 - factorized_top_k/top_5_categorical_accuracy: 0.0022 - factorized_top_k/top_10_categorical_accuracy: 0.0030 - factorized_top_k/top_50_categorical_accuracy: 0.0097 - factorized_top_k/top_100_categorical_accuracy: 0.0171 - loss: 6382.5906 - regularization_loss: 0.0000e+00 - total_loss: 6382.5906 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_100_categorical_accuracy: 0.0013 - val_loss: 7030.6104 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7030.6104
# Epoch 3/10
# 70/70 [==============================] - 280s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.0122 - factorized_top_k/top_5_categorical_accuracy: 0.0233 - factorized_top_k/top_10_categorical_accuracy: 0.0342 - factorized_top_k/top_50_categorical_accuracy: 0.0924 - factorized_top_k/top_100_categorical_accuracy: 0.1436 - loss: 4679.3493 - regularization_loss: 0.0000e+00 - total_loss: 4679.3493 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 6.6667e-05 - val_factorized_top_k/top_50_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_100_categorical_accuracy: 6.6667e-04 - val_loss: 7355.6636 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7355.6636
# Epoch 4/10
# 70/70 [==============================] - 281s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.0560 - factorized_top_k/top_5_categorical_accuracy: 0.1088 - factorized_top_k/top_10_categorical_accuracy: 0.1478 - factorized_top_k/top_50_categorical_accuracy: 0.3019 - factorized_top_k/top_100_categorical_accuracy: 0.3991 - loss: 3106.3694 - regularization_loss: 0.0000e+00 - total_loss: 3106.3694 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 6.6667e-05 - val_factorized_top_k/top_10_categorical_accuracy: 6.6667e-05 - val_factorized_top_k/top_50_categorical_accuracy: 2.0000e-04 - val_factorized_top_k/top_100_categorical_accuracy: 7.3333e-04 - val_loss: 7480.1943 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7480.1943
# Epoch 5/10
# 70/70 [==============================] - 333s 5s/step - factorized_top_k/top_1_categorical_accuracy: 0.1892 - factorized_top_k/top_5_categorical_accuracy: 0.2554 - factorized_top_k/top_10_categorical_accuracy: 0.2910 - factorized_top_k/top_50_categorical_accuracy: 0.4098 - factorized_top_k/top_100_categorical_accuracy: 0.4704 - loss: 2554.3278 - regularization_loss: 0.0000e+00 - total_loss: 2554.3278 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_100_categorical_accuracy: 5.3333e-04 - val_loss: 7546.5488 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7546.5488
# Epoch 6/10
# 70/70 [==============================] - 285s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.3138 - factorized_top_k/top_5_categorical_accuracy: 0.3599 - factorized_top_k/top_10_categorical_accuracy: 0.3841 - factorized_top_k/top_50_categorical_accuracy: 0.4569 - factorized_top_k/top_100_categorical_accuracy: 0.4931 - loss: 2107.6110 - regularization_loss: 0.0000e+00 - total_loss: 2107.6110 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 6.6667e-05 - val_factorized_top_k/top_50_categorical_accuracy: 6.0000e-04 - val_factorized_top_k/top_100_categorical_accuracy: 0.0011 - val_loss: 7662.8008 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7662.8008
# Epoch 7/10
# 70/70 [==============================] - 283s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.3287 - factorized_top_k/top_5_categorical_accuracy: 0.3603 - factorized_top_k/top_10_categorical_accuracy: 0.3759 - factorized_top_k/top_50_categorical_accuracy: 0.4264 - factorized_top_k/top_100_categorical_accuracy: 0.4504 - loss: 1783.6218 - regularization_loss: 0.0000e+00 - total_loss: 1783.6218 - val_factorized_top_k/top_1_categorical_accuracy: 1.3333e-04 - val_factorized_top_k/top_5_categorical_accuracy: 1.3333e-04 - val_factorized_top_k/top_10_categorical_accuracy: 2.6667e-04 - val_factorized_top_k/top_50_categorical_accuracy: 5.3333e-04 - val_factorized_top_k/top_100_categorical_accuracy: 0.0012 - val_loss: 7837.4282 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7837.4282
# Epoch 8/10
# 70/70 [==============================] - 286s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.3404 - factorized_top_k/top_5_categorical_accuracy: 0.3640 - factorized_top_k/top_10_categorical_accuracy: 0.3768 - factorized_top_k/top_50_categorical_accuracy: 0.4168 - factorized_top_k/top_100_categorical_accuracy: 0.4364 - loss: 1579.8165 - regularization_loss: 0.0000e+00 - total_loss: 1579.8165 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_50_categorical_accuracy: 3.3333e-04 - val_factorized_top_k/top_100_categorical_accuracy: 9.3333e-04 - val_loss: 7984.2686 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7984.2686
# Epoch 9/10
# 70/70 [==============================] - 287s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.3290 - factorized_top_k/top_5_categorical_accuracy: 0.3488 - factorized_top_k/top_10_categorical_accuracy: 0.3592 - factorized_top_k/top_50_categorical_accuracy: 0.3937 - factorized_top_k/top_100_categorical_accuracy: 0.4112 - loss: 1417.1076 - regularization_loss: 0.0000e+00 - total_loss: 1417.1076 - val_factorized_top_k/top_1_categorical_accuracy: 6.6667e-05 - val_factorized_top_k/top_5_categorical_accuracy: 2.6667e-04 - val_factorized_top_k/top_10_categorical_accuracy: 2.6667e-04 - val_factorized_top_k/top_50_categorical_accuracy: 4.6667e-04 - val_factorized_top_k/top_100_categorical_accuracy: 6.0000e-04 - val_loss: 7971.0908 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7971.0908
# Epoch 10/10
# 70/70 [==============================] - 289s 4s/step - factorized_top_k/top_1_categorical_accuracy: 0.3538 - factorized_top_k/top_5_categorical_accuracy: 0.3702 - factorized_top_k/top_10_categorical_accuracy: 0.3797 - factorized_top_k/top_50_categorical_accuracy: 0.4103 - factorized_top_k/top_100_categorical_accuracy: 0.4254 - loss: 1286.8217 - regularization_loss: 0.0000e+00 - total_loss: 1286.8217 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 6.6667e-05 - val_factorized_top_k/top_10_categorical_accuracy: 6.6667e-05 - val_factorized_top_k/top_50_categorical_accuracy: 2.0000e-04 - val_factorized_top_k/top_100_categorical_accuracy: 6.6667e-04 - val_loss: 7998.5708 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7998.5708

# %% [markdown]
# ### NB: From the above result we can see that the model doesn't generalize well on our validation set. factors such as the depth and width of the model, activation function, learning rate, and optimizer can radically change the performance of the model.

# %% [markdown]
# ## Predicting or recommending for new user

# %%
# user BruteForce from factorized top-k

# creating the model that takes in raw query features
index = tfrs.layers.factorized_top_k.BruteForce(model.query_model)

# recommends movie out of the entire dataset
index.index_from_dataset(
    tf.data.Dataset.zip(
        (movie_titles.batch(100), movietitle_genres.batch(100).map(model.candidate_model))
)
)

# getting recommendations
# Get recommendations.
_, titles = index({'userID' : tf.constant(['ur0090329']), 'review date in unix': tf.constant([902185200.0]) })
print(f"Recommendations for user ur0090329: {titles[0, :5]}")
# Out:
# Recommendations for user ur0090329: [b"Buffalo '66" b"Buffalo '66" b"Buffalo '66" b"Buffalo '66"
#  b"Buffalo '66"]

# %% [markdown]
# # Since BruteForce is slow for serving a model with many possible candidates we explore approximate retrieval index

# %%
# Using FAISS for approximate retrieval operation
embedding_dimension = 32

# creating a distance based indices
faiss_index = faiss.IndexFlatL2(embedding_dimension)


# list to store movied ids. This will be used to retrieve the movie names later
movie_ids_list = []

# a function to index movie embeddings in FAISS
def index_movie_in_faiss(movies, movie_ids):
    # retrieve movie embeddings
    movie_embeddings = model.candidate_model(movies)

    # Check the shape of the embeddings
    print(f'shape of the movie_embeddings: {movie_embeddings.shape}')

    # convert to a numpy array
    movie_embeddings_np = movie_embeddings.numpy()

    # add the movie embeddings to the faiss index
    faiss_index.add(movie_embeddings_np)

    # Update the movie ID list (ensure the order is consistent)
    movie_ids_list.extend(movie_ids)  # Add the movie IDs of the current batch

    print(f'length of the variable - movie_ids_list: {len(movie_ids_list)}') # for observability

# %%
# function to perform similarity search
def search_top_k(user_id, k):
    # get the user embeddings and convert it to numpy array
    user_embeddings = model.query_model(user_id)
    user_embeddings_np = user_embeddings.numpy()

    # performing search in faiss index
    distances, indices = faiss_index.search(user_embeddings_np, k)

    # Print indices for debugging
    print(f"indices: {indices}")

    # Convert indices to movie IDs using the mapping
    recommended_movie_ids = []
    for index in indices:
        # print(index)
        movie_id_for_each_index = [movie_ids_list[i] for i in index] # Retrieve movie IDs for each index
        recommended_movie_ids.append(movie_id_for_each_index)

    return distances, recommended_movie_ids

# %%
movie_titles_with_ids =  df_tensor.map(lambda x: 
    {
    'movieID': x['movieID'],
    'originalTitle': x['originalTitle'],
    'genres': x['genres']
    
    }
)


for movie in movie_titles_with_ids.batch(100).as_numpy_iterator():
    # Assume movie_batch contains a list of movie features and movie_ids_batch is a list of IDs
    movie_ids_batch = [mov for mov in movie['movieID']]  # return the movie ids for the batch
    # print(f'length of the movie_ids for a 100 batch: {len(movie_ids_batch)}')
    index_movie_in_faiss(movie, movie_ids_batch)

# searching for the top k most similar movies for a user
user = {'userID' : tf.constant(['ur0090329']), 'review date in unix': tf.constant([902185200.0])}
distances, recommended_movie_ids = search_top_k(user, k=10)

# Print the recommended movie IDs for the user
print(f"Recommended Movie IDs: {recommended_movie_ids}")
# Out:
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 100900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 101900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 102900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 103900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 104900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 105900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 106900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 107900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 108900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 109900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 110900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 111900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 112900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 113900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 114900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 115900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 116900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 117900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 118900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 119900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 120900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 121900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 122900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 123900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 124900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 125900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 126900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 127900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 128900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 129900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 130900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 131900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 132900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 133900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 134900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 135900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 136900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 137900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 138900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 139900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 140900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 141900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 142900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 143900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 144900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 145900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 146900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 147900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 148900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 149900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 150900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 151900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 152900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 153900
# ...
# length of the variable - movie_ids_list: 182400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 182500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 182600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 182700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 182800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 182900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 183900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 184900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 185900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 186900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 187900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 188900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 189900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 190900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 191900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 192900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 193900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 194900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 195900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 196900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 197900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 198900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199000
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199100
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199200
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199300
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199400
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199500
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199600
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199700
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199800
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 199900
# shape of the movie_embeddings: (100, 32)
# length of the variable - movie_ids_list: 200000
# indices: [[ 69975 169975  13186  22963 113186 122963  22234 122234  46720  55845]]
# Recommended Movie IDs: [[b'tt0594078', b'tt0594078', b'tt0127045', b'tt0127045', b'tt0127045', b'tt0127045', b'tt0368185', b'tt0368185', b'tt0086650', b'tt0086650']]

# %%
for movie in movie_titles_with_ids.take(20).batch(10).as_numpy_iterator():
    print(movie['movieID'])
# Out:
# [b'tt0134619' b'tt0119822' b'tt0120746' b'tt0119668' b'tt0134619'
#  b'tt0120591' b'tt0120685' b'tt0120591' b'tt0120609' b'tt0114369']
# [b'tt0117887' b'tt0111309' b'tt0118789' b'tt0088040' b'tt0114694'
#  b'tt0119314' b'tt0107843' b'tt0116209' b'tt0017739' b'tt0120184']

# %%
# removing duplicates from result
final_movie_recommended_ids = list(dict.fromkeys(recommended_movie_ids[0]))
final_movie_recommended_ids
# Out:
# [b'tt0594078', b'tt0127045', b'tt0368185', b'tt0086650']

# %%
# converting byte strings to string
recommended_movie_str =[val.decode(encoding='utf-8') for val in final_movie_recommended_ids]
recommended_movie_str
# Out:
# ['tt0594078', 'tt0127045', 'tt0368185', 'tt0086650']

# %%
# FAISS Retrival class
class Faiss_retrieval_index():
    """ Using FAISS for approximate retrieval operation 
    
    * args:
    embedding_dimension: The dimension size of the vectors

    * model: This is the already compiled and trained_model
    """

    # list to store movie ids. This will be used to retrieve the movie names later
    movie_ids_list = []

    def __init__(self, embedding_dimension, model):
        self.embedding_dimension = embedding_dimension
        self.movie_model = model.candidate_model
        self.query_model = model.query_model
        # creating a distance based indices
        self.faiss_index = faiss.IndexFlatL2(self.embedding_dimension)


    # a function to index movie embeddings in FAISS
    def index_movie_in_faiss(self, movies, movie_ids):
        """ function that index movie embeddings

        args:
        * movies -  a batch of movie title list derived from a tensor dataset

        * movie_ids - the ids of the batch of movie title list
        
        """
        # retrieve movie embeddings
        movie_embeddings = self.movie_model(movies)

        # convert to a numpy array
        movie_embeddings_np = movie_embeddings.numpy()

        # add the movie embeddings to the faiss index
        self.faiss_index.add(movie_embeddings_np)

        # Update the movie ID list (ensure the order is consistent)
        movie_ids_list.extend(movie_ids)  # Add the movie IDs of the current batch

    
    # function to perform similarity search
    def search_top_k(self, user_id, k):
        """ perform similarity search of the query with the existing embeddings
        
        args:
        * user_id: the id which represents the query we hope to find a result for

        * k: the number of possible result to be returned
        """

        # get the user embeddings and convert it to numpy array
        user_embeddings = self.query_model(user_id)
        user_embeddings_np = user_embeddings.numpy()

        # performing search in faiss index
        distances, indices = self.faiss_index.search(user_embeddings_np, k)

        # Convert indices to movie IDs using the mapping
        recommended_movie_ids = []
        for index in indices:
            # print(index)
            movie_id_for_each_index = [movie_ids_list[i] for i in index] # Retrieve movie IDs for each index
            recommended_movie_ids.append(movie_id_for_each_index)

        return distances, recommended_movie_ids

# %%
faiss_retrieval =  Faiss_retrieval_index(embedding_dimension=32, model=model)
movie_titles_with_ids =  df_tensor.map(lambda x: 
    {
    'movieID': x['movieID'],
    'originalTitle': x['originalTitle'],
    'genres': x['genres']
    }
)


for movie in movie_titles_with_ids.batch(100).as_numpy_iterator():
    movie_ids_batch = [mov for mov in movie['movieID']]  # return the movie ids for the batch
    faiss_retrieval.index_movie_in_faiss(movie, movie_ids_batch)

# searching for the top k most similar movies for a user
user = {'userID' : tf.constant(['ur0090329']), 'review date in unix': tf.constant([902185200.0])}
distances, recommended_movie_ids = faiss_retrieval.search_top_k(user, k=50)

# removing duplicates from result
final_movie_recommended_ids = list(dict.fromkeys(recommended_movie_ids[0]))

# converting byte strings to string
recommended_movie_str =[val.decode(encoding='utf-8') for val in final_movie_recommended_ids]

recommended_movies = [df[df['movieID']== id]['originalTitle'].values[0] for id in recommended_movie_str]

# Print the recommended movies for the user
print(f"Recommended Movies: {recommended_movies}")
# Out:
# Recommended Movies: ['Dirt', 'Neon Maniacs', 'Puni Puni Poemi', '√Ä nos amours', 'Meet the Fockers', 'All Through the Night', 'Buddy', 'Buddy', 'Night of the Wolf', 'Broadway Melody of 1936', 'Scaredy Cat', 'Mixed Nuts', 'Mixed Nuts', "Von Ryan's Express", 'The River', 'The River', 'The River', 'How to Make a Monster', 'How to Make a Monster']
